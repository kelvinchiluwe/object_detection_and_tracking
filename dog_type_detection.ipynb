# %%
import tensorflow as tf
import os 
import xml.etree.ElementTree as ET
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.layers import Input,GlobalMaxPooling2D,Dense

# %%
image_directory='images'
annotation_dir='Annotations'
classes={'english_springer':0,'westhighland_terrier':1,'irish_wolfhound':2,'bull_mastiff':3,'whippet':4}

# %%
def parse_voc_annotations(annotation_dir,image_directory,classes):
    img_path=[]
    bbox_data=[]
    class_labels=[]
    for xml_file in sorted(os.listdir(annotation_dir)):
        if not xml_file.endswith('.xml'):
            # print(xml_file)
            continue
        
        tree=ET.parse(os.path.join(annotation_dir,xml_file))
        # print(tree)
        root= tree.getroot()
        # print(root)
        img_file_name=root.find('filename').text
        # print(img_file_name)
        path=os.path.join(image_directory,img_file_name)
        # print(path)
        size=root.find('size')
        # print(size)
        img_width=int(size.find('width').text)
        # print(img_width)
        img_height=int(size.find('height').text)

        objects=root.find('object')
        # print(objects)
        if objects is not None:
            class_name=objects.find('name').text
            # print(class_name)
            if class_name not in classes:
                continue
            # img_path.append(class_name)
            class_id=classes[class_name]
            # print(class_id)

            bnbox=objects.find('bndbox')
            xmin=float(bnbox.find('xmin').text) / img_width
            ymin=float(bnbox.find('ymin').text) / img_height
            xmax=float(bnbox.find('xmax').text) / img_width
            ymax=float(bnbox.find('ymax').text) / img_height
            img_path.append(path)
            bbox_data.append([xmin, ymin, xmax, ymax])
            class_labels.append(class_id)
    return img_path,bbox_data,class_labels

# %%
parse_voc_annotations(annotation_dir=annotation_dir,image_directory=image_directory,classes=classes)
# Out:
# (['images\\0123c356-irish_wolfhound_20.jpg',
#   'images\\02f775b8-english_springer_6.jpg',
#   'images\\0348655e-english_springer_27.jpg',
#   'images\\03cdf529-irish_wolfhound_16.jpg',
#   'images\\054b16ed-english_springer_31.jpg',
#   'images\\06d7520a-bull_mastiff_6.jpg',
#   'images\\08a05225-irish_wolfhound_17.jpg',
#   'images\\08cc69b3-english_springer_3.jpg',
#   'images\\093a451b-whippet_77.jpg',
#   'images\\09e772ce-english_springer_24.jpg',
#   'images\\0b3e051b-whippet_93.jpg',
#   'images\\0cb2a82d-whippet_92.jpg',
#   'images\\0f72e9ec-english_springer_35.jpg',
#   'images\\146a3c29-whippet_99.jpg',
#   'images\\16207c28-irish_wolfhound_23.jpg',
#   'images\\1d530f65-irish_wolfhound_37.jpg',
#   'images\\1dc190c7-whippet_83.jpg',
#   'images\\1e7b8aab-english_springer_42.jpg',
#   'images\\1eaa750f-bull_mastiff_39.jpg',
#   'images\\1ef0ed4f-english_springer_26.jpg',
#   'images\\2194e49a-bull_mastiff_33.jpg',
#   'images\\21b8ba9e-english_springer_28.jpg',
#   'images\\25190a2d-english_springer_22.jpg',
#   'images\\263f289c-irish_wolfhound_27.jpg',
#   'images\\29d0682e-english_springer_50.jpg',
#   'images\\2b62618e-irish_wolfhound_29.jpg',
#   'images\\2cad7695-whippet_5.jpg',
#   'images\\2e32ac5f-irish_wolfhound_34.jpg',
#   'images\\301a03ca-english_springer_21.jpg',
#   'images\\31cb3253-irish_wolfhound_5.jpg',
#   'images\\329b4963-bull_mastiff_26.jpg',
#   'images\\346bd414-whippet_80.jpg',
#   'images\\37ff6139-irish_wolfhound_38.jpg',
#   'images\\38055054-whippet_96.jpg',
#   'images\\38f10bc9-whippet_73.jpg',
#   'images\\3ae3bfb3-english_springer_25.jpg',
#   'images\\3d38dd0f-irish_wolfhound_31.jpg',
#   'images\\408ac114-bull_mastiff_15.jpg',
#   'images\\40d405c5-bull_mastiff_35.jpg',
#   'images\\4224c02b-english_springer_44.jpg',
#   'images\\46f7dbf2-irish_wolfhound_6.jpg',
#   'images\\47037d77-irish_wolfhound_24.jpg',
#   'images\\4b010a39-english_springer_30.jpg',
#   'images\\4e09cbc4-english_springer_36.jpg',
#   'images\\4f055a3d-irish_wolfhound_30.jpg',
#   'images\\4f63f26d-whippet_8.jpg',
#   'images\\50a169b3-whippet_2.jpg',
#   'images\\50d81418-irish_wolfhound_14.jpg',
#   'images\\51775621-whippet_76.jpg',
#   'images\\521b32f6-whippet_89.jpg',
#   'images\\54070032-bull_mastiff_19.jpg',
#   'images\\5553d1ce-whippet_87.jpg',
#   'images\\5651a386-bull_mastiff_11.jpg',
#   'images\\58aa909b-irish_wolfhound_4.jpg',
#   'images\\5d40ad79-irish_wolfhound_1.jpg',
#   'images\\5d96bcf2-whippet_4.jpg',
#   'images\\5dcc4ca8-bull_mastiff_7.jpg',
#   'images\\600d6564-english_springer_39.jpg',
#   'images\\66c5f8b3-english_springer_4.jpg',
#   'images\\67027ab9-irish_wolfhound_32.jpg',
#   'images\\673d9dcc-whippet_78.jpg',
#   'images\\678b5c13-bull_mastiff_25.jpg',
#   'images\\68e821b6-english_springer_38.jpg',
#   'images\\690b1cb9-whippet_84.jpg',
#   'images\\6932444d-whippet_12.jpg',
#   'images\\6a1ab30a-bull_mastiff_18.jpg',
#   'images\\6a78d1fc-whippet_97.jpg',
#   'images\\6a88f64d-bull_mastiff_30.jpg',
#   'images\\6fab7ae6-irish_wolfhound_36.jpg',
#   'images\\70fc2c92-irish_wolfhound_26.jpg',
#   'images\\7133ba12-bull_mastiff_2.jpg',
#   'images\\722520d8-bull_mastiff_16.jpg',
#   'images\\723c7b53-whippet_91.jpg',
#   'images\\751f8029-whippet_98.jpg',
#   'images\\7838ffdf-bull_mastiff_13.jpg',
#   'images\\7b352471-bull_mastiff_20.jpg',
#   'images\\7bac46df-whippet_9.jpg',
#   'images\\7dafc642-english_springer_37.jpg',
#   'images\\7dd637d2-bull_mastiff_27.jpg',
#   'images\\7e1226be-whippet_7.jpg',
#   'images\\80c05668-english_springer_29.jpg',
#   'images\\80ff91b7-bull_mastiff_32.jpg',
#   'images\\837585b5-whippet_81.jpg',
#   'images\\8442aab8-irish_wolfhound_2.jpg',
#   'images\\856ce08d-irish_wolfhound_39.jpg',
#   'images\\8641d26d-english_springer_32.jpg',
#   'images\\867fc7c1-whippet_3.jpg',
#   'images\\8754ce60-english_springer_49.jpg',
#   'images\\883ec82c-bull_mastiff_22.jpg',
#   'images\\8a181028-bull_mastiff_28.jpg',
#   'images\\8c64a0b5-english_springer_48.jpg',
#   'images\\8f944285-irish_wolfhound_7.jpg',
#   'images\\928ef5e1-english_springer_51.jpg',
#   'images\\933a7e0b-bull_mastiff_1.jpg',
#   'images\\94e4150a-whippet_74.jpg',
#   'images\\96ecbaf7-bull_mastiff_36.jpg',
#   'images\\985703a0-english_springer_7.jpg',
#   'images\\98889629-bull_mastiff_37.jpg',
#   'images\\9c8d2784-irish_wolfhound_28.jpg',
#   'images\\9cb06c30-bull_mastiff_38.jpg',
#   'images\\9fefa373-whippet_85.jpg',
#   'images\\a0204a49-irish_wolfhound_10.jpg',
#   'images\\a155bb49-english_springer_33.jpg',
#   'images\\a1cef85c-irish_wolfhound_33.jpg',
#   'images\\a27f9a70-irish_wolfhound_40.jpg',
#   'images\\a3dd8462-english_springer_47.jpg',
#   'images\\a6bd95ab-whippet_11.jpg',
#   'images\\a8bdd4bf-english_springer_2.jpg',
#   'images\\aa1fd2db-irish_wolfhound_13.jpg',
#   'images\\aa2ed80c-bull_mastiff_34.jpg',
#   'images\\abc72997-whippet_72.jpg',
#   'images\\ac5f1176-irish_wolfhound_21.jpg',
#   'images\\adc0f790-whippet_88.jpg',
#   'images\\b387d3fb-whippet_90.jpg',
#   'images\\b3eaa096-english_springer_20.jpg',
#   'images\\b49317e9-bull_mastiff_8.jpg',
#   'images\\b4b46d6e-bull_mastiff_10.jpg',
#   'images\\b7cff271-whippet_79.jpg',
#   'images\\b9a2b981-irish_wolfhound_11.jpg',
#   'images\\b9d32887-irish_wolfhound_3.jpg',
#   'images\\bd169100-irish_wolfhound_9.jpg',
#   'images\\bef4da58-irish_wolfhound_35.jpg',
#   'images\\bf20e2db-english_springer_40.jpg',
#   'images\\c1582d92-bull_mastiff_29.jpg',
#   'images\\c5f5da74-english_springer_5.jpg',
#   'images\\cb3a62cc-english_springer_23.jpg',
#   'images\\cce60f1f-whippet_82.jpg',
#   'images\\cd3185cf-bull_mastiff_9.jpg',
#   'images\\cfa3be28-irish_wolfhound_8.jpg',
#   'images\\cfddbb19-irish_wolfhound_19.jpg',
#   'images\\d08acecd-whippet_86.jpg',
#   'images\\d205b363-whippet_95.jpg',
#   'images\\d3cc5d76-bull_mastiff_17.jpg',
#   'images\\d470f6c7-bull_mastiff_24.jpg',
#   'images\\d490e878-bull_mastiff_3.jpg',
#   'images\\d50430b5-irish_wolfhound_25.jpg',
#   'images\\d66556a9-bull_mastiff_40.jpg',
#   'images\\d66f9a7a-whippet_75.jpg',
#   'images\\d93f4c7e-whippet_1.jpg',
#   'images\\d9651a00-bull_mastiff_31.jpg',
#   'images\\da287d09-english_springer_43.jpg',
#   'images\\dc68a754-english_springer_41.jpg',
#   'images\\dcb627b6-english_springer_8.jpg',
#   'images\\dccd68f1-bull_mastiff_21.jpg',
#   'images\\dcfd0094-bull_mastiff_12.jpg',
#   'images\\dddfbd8b-english_springer_46.jpg',
#   'images\\df018377-bull_mastiff_5.jpg',
#   'images\\e0f3ebb3-whippet_94.jpg',
#   'images\\e3fca2f7-english_springer_45.jpg',
#   'images\\e4330497-bull_mastiff_4.jpg',
#   'images\\e4fdf640-whippet_6.jpg',
#   'images\\e83165d6-irish_wolfhound_12.jpg',
#   'images\\eb83ca55-irish_wolfhound_22.jpg',
#   'images\\f2f59531-english_springer_9.jpg',
#   'images\\f37e1446-whippet_10.jpg',
#   'images\\f5a3df13-bull_mastiff_23.jpg',
#   'images\\f6065403-irish_wolfhound_15.jpg',
#   'images\\fbd5b57a-english_springer_34.jpg',
#   'images\\fc22561b-irish_wolfhound_18.jpg',
#   'images\\feefdc17-bull_mastiff_14.jpg'],
#  [[0.24924924924924924, 0.002, 0.8528528528528528, 0.998],
#   [0.03081232492997199, 0.032, 0.8907563025210085, 0.998],
#   [0.12533333333333332, 0.044, 0.9413333333333334, 0.996],
#   [0.104, 0.004651162790697674, 0.904, 0.8930232558139535],
#   [0.06788511749347259, 0.032, 0.8929503916449086, 0.998],
#   [0.152, 0.21066666666666667, 0.776, 0.9973333333333333],
#   [0.03003003003003003, 0.044, 0.996996996996997, 0.998],
#   [0.266, 0.24266666666666667, 0.542, 0.9786666666666667],
#   [0.018, 0.03, 0.988, 0.9633333333333334],
#   [0.332, 0.03761061946902655, 0.978, 0.9734513274336283],
#   [0.296, 0.3388704318936877, 0.904, 0.7840531561461794],
#   [0.3025, 0.07335907335907337, 0.9575, 0.9922779922779923],
#   [0.246, 0.06666666666666667, 0.722, 0.23733333333333334],
#   [0.0, 0.013333333333333334, 0.998, 0.9786666666666667],
#   [0.342, 0.384, 0.644, 0.7333333333333333],
#   [0.17302052785923755, 0.16015625, 0.7390029325513197, 0.970703125],
#   [0.248, 0.1056701030927835, 0.96, 0.8814432989690721],
#   [0.29, 0.010666666666666666, 0.998, 0.7626666666666667],
#   [0.0026666666666666666, 0.012, 0.9866666666666667, 0.998],
#   [0.242, 0.4266666666666667, 0.49, 0.864],
#   [0.022, 0.021333333333333333, 0.938, 0.8773333333333333],
#   [0.216, 0.146, 0.8133333333333334, 0.89],
#   [0.036, 0.009009009009009009, 0.998, 0.996996996996997],
#   [0.25, 0.018018018018018018, 0.838, 0.9519519519519519],
#   [0.128, 0.06933333333333333, 0.926, 0.9866666666666667],
#   [0.0, 0.03, 1.0, 0.998],
#   [0.3286118980169972,
#    0.0326975476839237,
#    0.7988668555240793,
#    0.9155313351498637],
#   [0.09, 0.19519519519519518, 0.56, 0.9129129129129129],
#   [0.218, 0.029940119760479042, 0.674, 0.9161676646706587],
#   [0.11614730878186968, 0.088, 0.9971671388101983, 0.998],
#   [0.0125, 0.0196078431372549, 0.9325, 0.9803921568627451],
#   [0.0, 0.08100558659217877, 0.798, 0.7849162011173184],
#   [0.204, 0.1111111111111111, 0.688, 0.996996996996997],
#   [0.554, 0.24415584415584415, 0.882, 0.9974025974025974],
#   [0.20266666666666666, 0.318, 0.9306666666666666, 0.626],
#   [0.306, 0.02666666666666667, 0.902, 0.9786666666666667],
#   [0.08857142857142856,
#    0.013422818791946308,
#    0.9428571428571428,
#    0.9966442953020134],
#   [0.2859375, 0.08958333333333333, 0.6203125, 0.9979166666666667],
#   [0.13866666666666666, 0.448, 0.6746666666666666, 0.966],
#   [0.07582938388625593, 0.034, 0.9312796208530806, 0.998],
#   [0.022, 0.21066666666666667, 0.998, 0.9333333333333333],
#   [0.008, 0.21921921921921922, 0.648, 0.990990990990991],
#   [0.036, 0.013927576601671309, 0.998, 0.9944289693593314],
#   [0.23076923076923078, 0.016, 0.8816568047337278, 0.994],
#   [0.4, 0.060240963855421686, 0.974, 0.8825301204819277],
#   [0.192, 0.4194528875379939, 0.376, 0.8844984802431611],
#   [0.456, 0.30857142857142855, 0.854, 0.8542857142857143],
#   [0.17717717717717718, 0.044, 0.996996996996997, 0.998],
#   [0.39, 0.136, 0.998, 0.6],
#   [0.072, 0.2206703910614525, 0.628, 0.8743016759776536],
#   [0.1018867924528302,
#    0.013888888888888888,
#    0.9924528301886792,
#    0.9722222222222222],
#   [0.196, 0.128, 0.762, 0.9973333333333333],
#   [0.0, 0.02304147465437788, 0.98, 0.9953917050691244],
#   [0.292, 0.036036036036036036, 0.748, 0.9129129129129129],
#   [0.056, 0.33774834437086093, 0.938, 0.9271523178807947],
#   [0.374, 0.4735376044568245, 0.932, 0.9805013927576601],
#   [0.008, 0.004, 0.8693333333333333, 0.998],
#   [0.36, 0.18133333333333335, 0.998, 0.9973333333333333],
#   [0.374, 0.20266666666666666, 0.79, 0.9973333333333333],
#   [0.0, 0.11884057971014493, 0.98, 0.9942028985507246],
#   [0.088, 0.112, 0.63, 0.8373333333333334],
#   [0.16, 0.06906906906906907, 0.724, 0.996996996996997],
#   [0.094, 0.11752136752136752, 0.878, 0.9978632478632479],
#   [0.028, 0.005333333333333333, 0.868, 0.8346666666666667],
#   [0.15288220551378445, 0.422, 0.8922305764411027, 0.86],
#   [0.06, 0.08533333333333333, 0.968, 0.5013333333333333],
#   [0.572, 0.424, 0.79, 0.6746666666666666],
#   [0.218, 0.224, 0.982, 0.9973333333333333],
#   [0.014, 0.08, 0.998, 0.9973333333333333],
#   [0.15413533834586465, 0.11, 0.8571428571428571, 0.995],
#   [0.116, 0.06701030927835051, 0.998, 0.9974226804123711],
#   [0.009009009009009009, 0.016, 0.993993993993994, 0.998],
#   [0.008, 0.17417417417417416, 0.906, 0.987987987987988],
#   [0.222, 0.2132132132132132, 0.732, 0.8528528528528528],
#   [0.0035335689045936395,
#    0.1455026455026455,
#    0.9540636042402827,
#    0.9973544973544973],
#   [0.448, 0.216, 0.866, 0.9946666666666667],
#   [0.442, 0.35435435435435436, 0.974, 0.9129129129129129],
#   [0.5, 0.1921921921921922, 0.984, 0.996996996996997],
#   [0.08, 0.238, 0.784, 0.884],
#   [0.082, 0.026737967914438502, 0.872, 0.983957219251337],
#   [0.1935483870967742, 0.032, 0.8548387096774194, 0.936],
#   [0.0, 0.037333333333333336, 0.764, 0.9973333333333333],
#   [0.042, 0.088, 0.862, 0.998],
#   [0.218, 0.0, 0.824, 0.9973333333333333],
#   [0.02335766423357664,
#    0.0285204991087344,
#    0.9474452554744526,
#    0.9090909090909091],
#   [0.39714285714285713,
#    0.015209125475285171,
#    0.8514285714285714,
#    0.9961977186311787],
#   [0.16, 0.23376623376623376, 0.878, 0.8733766233766234],
#   [0.368, 0.0, 0.986, 1.0],
#   [0.0, 0.032640949554896145, 0.978328173374613, 0.9851632047477745],
#   [0.018, 0.07588075880758807, 0.906, 0.997289972899729],
#   [0.266, 0.03303303303303303, 0.726, 0.996996996996997],
#   [0.102, 0.11711711711711711, 0.998, 0.996996996996997],
#   [0.24089635854341737, 0.08, 0.896358543417367, 0.932],
#   [0.008, 0.016, 0.998, 0.9973333333333333],
#   [0.002, 0.18618618618618618, 0.718, 0.996996996996997],
#   [0.402, 0.31466666666666665, 0.798, 0.9973333333333333],
#   [0.10666666666666667, 0.088, 0.9946666666666667, 0.958],
#   [0.068, 0.0650887573964497, 0.846, 0.9970414201183432],
#   [0.112, 0.23733333333333334, 0.96, 0.8826666666666667],
#   [0.0, 0.07692307692307693, 0.574, 0.9970414201183432],
#   [0.06, 0.1225071225071225, 0.72, 0.8176638176638177],
#   [0.342, 0.2986666666666667, 0.822, 0.848],
#   [0.03, 0.10810810810810811, 0.86, 0.993993993993994],
#   [0.08132530120481928, 0.024, 0.9969879518072289, 0.948],
#   [0.0, 0.2740112994350282, 0.664, 0.9689265536723164],
#   [0.07474747474747474, 0.03, 0.8646464646464647, 0.996],
#   [0.34, 0.2948328267477204, 0.798, 0.8449848024316109],
#   [0.168, 0.015015015015015015, 0.998, 0.990990990990991],
#   [0.02666666666666667, 0.104, 0.9973333333333333, 0.72],
#   [0.08108108108108109, 0.318, 0.933933933933934, 0.998],
#   [0.008, 0.07238605898123325, 0.712, 0.8123324396782842],
#   [0.02666666666666667,
#    0.015873015873015872,
#    0.9466666666666667,
#    0.996031746031746],
#   [0.5, 0.324, 0.7520325203252033, 0.922],
#   [0.35833333333333334, 0.01838235294117647, 0.7375, 0.6213235294117647],
#   [0.29, 0.01, 0.9975, 0.9966666666666667],
#   [0.078, 0.21333333333333335, 0.468, 0.568],
#   [0.012, 0.0, 0.74, 0.9969879518072289],
#   [0.4789156626506024, 0.408, 0.7680722891566265, 0.974],
#   [0.17, 0.13442622950819672, 0.998, 0.8229508196721311],
#   [0.012, 0.018617021276595744, 0.714, 0.9973404255319149],
#   [0.012, 0.30666666666666664, 0.572, 0.936],
#   [0.162, 0.09066666666666667, 0.94, 0.7706666666666667],
#   [0.002, 0.15269461077844312, 0.804, 0.8982035928143712],
#   [0.17, 0.3626666666666667, 0.502, 0.7226666666666667],
#   [0.214, 0.12612612612612611, 0.804, 0.993993993993994],
#   [0.1879432624113475,
#    0.29743589743589743,
#    0.7907801418439716,
#    0.9948717948717949],
#   [0.208, 0.3123123123123123, 0.8, 0.8168168168168168],
#   [0.152, 0.02666666666666667, 0.878, 0.9973333333333333],
#   [0.052, 0.2972972972972973, 0.502, 0.9669669669669669],
#   [0.05803571428571429,
#    0.012711864406779662,
#    0.9464285714285714,
#    0.923728813559322],
#   [0.072, 0.058666666666666666, 0.966, 0.6346666666666667],
#   [0.218, 0.35014005602240894, 0.412, 0.938375350140056],
#   [0.284, 0.176, 0.6, 0.8693333333333333],
#   [0.022321428571428572,
#    0.006711409395973154,
#    0.7901785714285714,
#    0.9966442953020134],
#   [0.0, 0.007168458781362007, 0.998, 0.956989247311828],
#   [0.1015625, 0.3888888888888889, 0.8854166666666666, 0.875],
#   [0.234, 0.08, 0.912, 0.9466666666666667],
#   [0.3375, 0.375, 0.7729166666666667, 0.7042682926829268],
#   [0.007342143906020558,
#    0.029754204398447608,
#    0.9765051395007343,
#    0.9987063389391979],
#   [0.02666666666666667, 0.068, 0.9973333333333333, 0.998],
#   [0.10333333333333333,
#    0.050793650793650794,
#    0.9466666666666667,
#    0.9492063492063492],
#   [0.06606606606606606, 0.196, 0.8678678678678678, 0.958],
#   [0.25, 0.03003003003003003, 0.998, 0.996996996996997],
#   [0.021021021021021023, 0.04, 0.996996996996997, 0.998],
#   [0.364, 0.21866666666666668, 0.704, 0.9973333333333333],
#   [0.02, 0.015105740181268883, 0.802, 0.9969788519637462],
#   [0.138, 0.029333333333333333, 0.58, 0.9653333333333334],
#   [0.136, 0.21963824289405684, 0.922, 0.834625322997416],
#   [0.404, 0.16216216216216217, 0.998, 0.975975975975976],
#   [0.08898305084745763, 0.132, 0.8961864406779662, 0.992],
#   [0.31, 0.0782608695652174, 0.69, 0.9971014492753624],
#   [0.284, 0.2702702702702703, 0.602, 0.9309309309309309],
#   [0.166, 0.3123123123123123, 0.342, 0.7477477477477478],
#   [0.06133333333333333, 0.036, 0.9973333333333333, 0.998],
#   [0.064, 0.1634349030470914, 0.866, 0.814404432132964],
#   [0.06, 0.11733333333333333, 0.738, 0.9973333333333333],
#   [0.312, 0.018018018018018018, 0.998, 0.996996996996997],
#   [0.030848329048843187, 0.006, 0.987146529562982, 0.998],
#   [0.08108108108108109, 0.064, 0.948948948948949, 0.998],
#   [0.002, 0.0072992700729927005, 0.554, 0.8722627737226277]],
#  [2,
#   0,
#   0,
#   2,
#   0,
#   3,
#   2,
#   0,
#   4,
#   0,
#   4,
#   4,
#   0,
#   4,
#   2,
#   2,
#   4,
#   0,
#   3,
#   0,
#   3,
#   0,
#   0,
#   2,
#   0,
#   2,
#   4,
#   2,
#   0,
#   2,
#   3,
#   4,
#   2,
#   4,
#   4,
#   0,
#   2,
#   3,
#   3,
#   0,
#   2,
#   2,
#   0,
#   0,
#   2,
#   4,
#   4,
#   2,
#   4,
#   4,
#   3,
#   4,
#   3,
#   2,
#   2,
#   4,
#   3,
#   0,
#   0,
#   2,
#   4,
#   3,
#   0,
#   4,
#   4,
#   3,
#   4,
#   3,
#   2,
#   2,
#   3,
#   3,
#   4,
#   4,
#   3,
#   3,
#   4,
#   0,
#   3,
#   4,
#   0,
#   3,
#   4,
#   2,
#   2,
#   0,
#   4,
#   0,
#   3,
#   3,
#   0,
#   2,
#   0,
#   3,
#   4,
#   3,
#   0,
#   3,
#   2,
#   3,
#   4,
#   2,
#   0,
#   2,
#   2,
#   0,
#   4,
#   0,
#   2,
#   3,
#   4,
#   2,
#   4,
#   4,
#   0,
#   3,
#   3,
#   4,
#   2,
#   2,
#   2,
#   2,
#   0,
#   3,
#   0,
#   0,
#   4,
#   3,
#   2,
#   2,
#   4,
#   4,
#   3,
#   3,
#   3,
#   2,
#   3,
#   4,
#   4,
#   3,
#   0,
#   0,
#   0,
#   3,
#   3,
#   0,
#   3,
#   4,
#   0,
#   3,
#   4,
#   2,
#   2,
#   0,
#   4,
#   3,
#   2,
#   0,
#   2,
#   3])

# %%
img_path,bnbox_data,class_labels=parse_voc_annotations(annotation_dir=annotation_dir,image_directory=image_directory,classes=classes)
img_path=tf.constant(img_path)
bnbox_data=tf.constant(bnbox_data,dtype=tf.float32)
class_labels=tf.constant(class_labels,dtype=tf.int32)

# %%
img_path
# Out:
# <tf.Tensor: shape=(160,), dtype=string, numpy=
# array([b'images\\0123c356-irish_wolfhound_20.jpg',
#        b'images\\02f775b8-english_springer_6.jpg',
#        b'images\\0348655e-english_springer_27.jpg',
#        b'images\\03cdf529-irish_wolfhound_16.jpg',
#        b'images\\054b16ed-english_springer_31.jpg',
#        b'images\\06d7520a-bull_mastiff_6.jpg',
#        b'images\\08a05225-irish_wolfhound_17.jpg',
#        b'images\\08cc69b3-english_springer_3.jpg',
#        b'images\\093a451b-whippet_77.jpg',
#        b'images\\09e772ce-english_springer_24.jpg',
#        b'images\\0b3e051b-whippet_93.jpg',
#        b'images\\0cb2a82d-whippet_92.jpg',
#        b'images\\0f72e9ec-english_springer_35.jpg',
#        b'images\\146a3c29-whippet_99.jpg',
#        b'images\\16207c28-irish_wolfhound_23.jpg',
#        b'images\\1d530f65-irish_wolfhound_37.jpg',
#        b'images\\1dc190c7-whippet_83.jpg',
#        b'images\\1e7b8aab-english_springer_42.jpg',
#        b'images\\1eaa750f-bull_mastiff_39.jpg',
#        b'images\\1ef0ed4f-english_springer_26.jpg',
#        b'images\\2194e49a-bull_mastiff_33.jpg',
#        b'images\\21b8ba9e-english_springer_28.jpg',
#        b'images\\25190a2d-english_springer_22.jpg',
#        b'images\\263f289c-irish_wolfhound_27.jpg',
#        b'images\\29d0682e-english_springer_50.jpg',
#        b'images\\2b62618e-irish_wolfhound_29.jpg',
#        b'images\\2cad7695-whippet_5.jpg',
#        b'images\\2e32ac5f-irish_wolfhound_34.jpg',
#        b'images\\301a03ca-english_springer_21.jpg',
#        b'images\\31cb3253-irish_wolfhound_5.jpg',
#        b'images\\329b4963-bull_mastiff_26.jpg',
#        b'images\\346bd414-whippet_80.jpg',
#        b'images\\37ff6139-irish_wolfhound_38.jpg',
#        b'images\\38055054-whippet_96.jpg',
#        b'images\\38f10bc9-whippet_73.jpg',
#        b'images\\3ae3bfb3-english_springer_25.jpg',
#        b'images\\3d38dd0f-irish_wolfhound_31.jpg',
#        b'images\\408ac114-bull_mastiff_15.jpg',
#        b'images\\40d405c5-bull_mastiff_35.jpg',
#        b'images\\4224c02b-english_springer_44.jpg',
#        b'images\\46f7dbf2-irish_wolfhound_6.jpg',
#        b'images\\47037d77-irish_wolfhound_24.jpg',
#        b'images\\4b010a39-english_springer_30.jpg',
#        b'images\\4e09cbc4-english_springer_36.jpg',
#        b'images\\4f055a3d-irish_wolfhound_30.jpg',
#        b'images\\4f63f26d-whippet_8.jpg',
#        b'images\\50a169b3-whippet_2.jpg',
#        b'images\\50d81418-irish_wolfhound_14.jpg',
#        b'images\\51775621-whippet_76.jpg',
#        b'images\\521b32f6-whippet_89.jpg',
#        b'images\\54070032-bull_mastiff_19.jpg',
#        b'images\\5553d1ce-whippet_87.jpg',
#        b'images\\5651a386-bull_mastiff_11.jpg',
#        b'images\\58aa909b-irish_wolfhound_4.jpg',
#        b'images\\5d40ad79-irish_wolfhound_1.jpg',
#        b'images\\5d96bcf2-whippet_4.jpg',
#        b'images\\5dcc4ca8-bull_mastiff_7.jpg',
#        b'images\\600d6564-english_springer_39.jpg',
#        b'images\\66c5f8b3-english_springer_4.jpg',
#        b'images\\67027ab9-irish_wolfhound_32.jpg',
#        b'images\\673d9dcc-whippet_78.jpg',
#        b'images\\678b5c13-bull_mastiff_25.jpg',
#        b'images\\68e821b6-english_springer_38.jpg',
#        b'images\\690b1cb9-whippet_84.jpg',
#        b'images\\6932444d-whippet_12.jpg',
#        b'images\\6a1ab30a-bull_mastiff_18.jpg',
#        b'images\\6a78d1fc-whippet_97.jpg',
#        b'images\\6a88f64d-bull_mastiff_30.jpg',
#        b'images\\6fab7ae6-irish_wolfhound_36.jpg',
#        b'images\\70fc2c92-irish_wolfhound_26.jpg',
#        b'images\\7133ba12-bull_mastiff_2.jpg',
#        b'images\\722520d8-bull_mastiff_16.jpg',
#        b'images\\723c7b53-whippet_91.jpg',
#        b'images\\751f8029-whippet_98.jpg',
#        b'images\\7838ffdf-bull_mastiff_13.jpg',
#        b'images\\7b352471-bull_mastiff_20.jpg',
#        b'images\\7bac46df-whippet_9.jpg',
#        b'images\\7dafc642-english_springer_37.jpg',
#        b'images\\7dd637d2-bull_mastiff_27.jpg',
#        b'images\\7e1226be-whippet_7.jpg',
#        b'images\\80c05668-english_springer_29.jpg',
#        b'images\\80ff91b7-bull_mastiff_32.jpg',
#        b'images\\837585b5-whippet_81.jpg',
#        b'images\\8442aab8-irish_wolfhound_2.jpg',
#        b'images\\856ce08d-irish_wolfhound_39.jpg',
#        b'images\\8641d26d-english_springer_32.jpg',
#        b'images\\867fc7c1-whippet_3.jpg',
#        b'images\\8754ce60-english_springer_49.jpg',
#        b'images\\883ec82c-bull_mastiff_22.jpg',
#        b'images\\8a181028-bull_mastiff_28.jpg',
#        b'images\\8c64a0b5-english_springer_48.jpg',
#        b'images\\8f944285-irish_wolfhound_7.jpg',
#        b'images\\928ef5e1-english_springer_51.jpg',
#        b'images\\933a7e0b-bull_mastiff_1.jpg',
#        b'images\\94e4150a-whippet_74.jpg',
#        b'images\\96ecbaf7-bull_mastiff_36.jpg',
#        b'images\\985703a0-english_springer_7.jpg',
#        b'images\\98889629-bull_mastiff_37.jpg',
#        b'images\\9c8d2784-irish_wolfhound_28.jpg',
#        b'images\\9cb06c30-bull_mastiff_38.jpg',
#        b'images\\9fefa373-whippet_85.jpg',
#        b'images\\a0204a49-irish_wolfhound_10.jpg',
#        b'images\\a155bb49-english_springer_33.jpg',
#        b'images\\a1cef85c-irish_wolfhound_33.jpg',
#        b'images\\a27f9a70-irish_wolfhound_40.jpg',
#        b'images\\a3dd8462-english_springer_47.jpg',
#        b'images\\a6bd95ab-whippet_11.jpg',
#        b'images\\a8bdd4bf-english_springer_2.jpg',
#        b'images\\aa1fd2db-irish_wolfhound_13.jpg',
#        b'images\\aa2ed80c-bull_mastiff_34.jpg',
#        b'images\\abc72997-whippet_72.jpg',
#        b'images\\ac5f1176-irish_wolfhound_21.jpg',
#        b'images\\adc0f790-whippet_88.jpg',
#        b'images\\b387d3fb-whippet_90.jpg',
#        b'images\\b3eaa096-english_springer_20.jpg',
#        b'images\\b49317e9-bull_mastiff_8.jpg',
#        b'images\\b4b46d6e-bull_mastiff_10.jpg',
#        b'images\\b7cff271-whippet_79.jpg',
#        b'images\\b9a2b981-irish_wolfhound_11.jpg',
#        b'images\\b9d32887-irish_wolfhound_3.jpg',
#        b'images\\bd169100-irish_wolfhound_9.jpg',
#        b'images\\bef4da58-irish_wolfhound_35.jpg',
#        b'images\\bf20e2db-english_springer_40.jpg',
#        b'images\\c1582d92-bull_mastiff_29.jpg',
#        b'images\\c5f5da74-english_springer_5.jpg',
#        b'images\\cb3a62cc-english_springer_23.jpg',
#        b'images\\cce60f1f-whippet_82.jpg',
#        b'images\\cd3185cf-bull_mastiff_9.jpg',
#        b'images\\cfa3be28-irish_wolfhound_8.jpg',
#        b'images\\cfddbb19-irish_wolfhound_19.jpg',
#        b'images\\d08acecd-whippet_86.jpg',
#        b'images\\d205b363-whippet_95.jpg',
#        b'images\\d3cc5d76-bull_mastiff_17.jpg',
#        b'images\\d470f6c7-bull_mastiff_24.jpg',
#        b'images\\d490e878-bull_mastiff_3.jpg',
#        b'images\\d50430b5-irish_wolfhound_25.jpg',
#        b'images\\d66556a9-bull_mastiff_40.jpg',
#        b'images\\d66f9a7a-whippet_75.jpg',
#        b'images\\d93f4c7e-whippet_1.jpg',
#        b'images\\d9651a00-bull_mastiff_31.jpg',
#        b'images\\da287d09-english_springer_43.jpg',
#        b'images\\dc68a754-english_springer_41.jpg',
#        b'images\\dcb627b6-english_springer_8.jpg',
#        b'images\\dccd68f1-bull_mastiff_21.jpg',
#        b'images\\dcfd0094-bull_mastiff_12.jpg',
#        b'images\\dddfbd8b-english_springer_46.jpg',
#        b'images\\df018377-bull_mastiff_5.jpg',
#        b'images\\e0f3ebb3-whippet_94.jpg',
#        b'images\\e3fca2f7-english_springer_45.jpg',
#        b'images\\e4330497-bull_mastiff_4.jpg',
#        b'images\\e4fdf640-whippet_6.jpg',
#        b'images\\e83165d6-irish_wolfhound_12.jpg',
#        b'images\\eb83ca55-irish_wolfhound_22.jpg',
#        b'images\\f2f59531-english_springer_9.jpg',
#        b'images\\f37e1446-whippet_10.jpg',
#        b'images\\f5a3df13-bull_mastiff_23.jpg',
#        b'images\\f6065403-irish_wolfhound_15.jpg',
#        b'images\\fbd5b57a-english_springer_34.jpg',
#        b'images\\fc22561b-irish_wolfhound_18.jpg',
#        b'images\\feefdc17-bull_mastiff_14.jpg'], dtype=object)>

# %%
def load_and_preprocess_image(path, bbox, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, [128, 128])
    label_encode = tf.one_hot(label, depth=len(classes))
    image = image / 255.0
    return image, {"class_output": label_encode, "box_output": bbox}

dataset= tf.data.Dataset.from_tensor_slices((img_path, bnbox_data, class_labels))
dataset = dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)


dataset = dataset.shuffle(buffer_size=196).batch(10).prefetch(tf.data.AUTOTUNE)


DATASET_SIZE = len(img_path)
train_size = int(0.8 * DATASET_SIZE)
train_ds = dataset.take(train_size)
val_ds = dataset.take(train_size)

# %%
print(f"img_path length: {len(img_path)}")
print(f"bnbox_data length: {len(bnbox_data)}")
print(f"class_labels length: {len(class_labels)}")
# Out:
# img_path length: 160
# bnbox_data length: 160
# class_labels length: 160

# %%
base_model=tf.keras.applications.MobileNetV2(
    input_shape=(128,128,3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable=False

# %%
input=Input(shape=(128,128,3))

# x=tf.keras.layers.RandomZoom(0.1)
# x=tf.keras.layers.RandomBrightness(0.2)(x)
# x=tf.keras.layers.RandomFlip('vertical and horizontal')(x)
# x=tf.keras.layers.Rescaling(1./255)(x)
x=base_model(input)

x=GlobalMaxPooling2D()(x)


class_output=tf.keras.layers.Dense(30,activation='relu')(x)
class_output=tf.keras.layers.Dense(5,activation='softmax',name='class_output')(class_output)

box_output=tf.keras.layers.Dense(30,activation='relu')(x)
box_output=tf.keras.layers.Dense(4,activation='sigmoid',name='box_output')(box_output)

detect_model=tf.keras.models.Model(inputs=input,outputs=[class_output,box_output])

# %%
detect_model.compile(
    optimizer='adam',
    loss={
        
        'class_output':'categorical_crossentropy',
        'box_output':'mse'
    },
    metrics={
        'class_output':'accuracy',
        'box_output':'mse'
    }
)

# %%
detect_model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds,
    callbacks=[
        EarlyStopping(monitor='val_class_output_accuracy',patience=3,restore_best_weights=True,mode='max'),
        ModelCheckpoint('dog_types.keras',monitor='val_class_output_loss',save_best_only=True,mode='min',verbose=1)
    ]
    
)
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - box_output_loss: 0.1077 - box_output_mse: 0.1077 - class_output_accuracy: 0.4555 - class_output_loss: 2.2193 - loss: 2.3269
# Epoch 1: val_class_output_loss improved from inf to 0.50703, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 295ms/step - box_output_loss: 0.1048 - box_output_mse: 0.1048 - class_output_accuracy: 0.4648 - class_output_loss: 2.1726 - loss: 2.2774 - val_box_output_loss: 0.0336 - val_box_output_mse: 0.0336 - val_class_output_accuracy: 0.8500 - val_class_output_loss: 0.5070 - val_loss: 0.5407
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - box_output_loss: 0.0354 - box_output_mse: 0.0354 - class_output_accuracy: 0.8415 - class_output_loss: 0.5903 - loss: 0.6257
# Epoch 2: val_class_output_loss improved from 0.50703 to 0.10347, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - box_output_loss: 0.0353 - box_output_mse: 0.0353 - class_output_accuracy: 0.8442 - class_output_loss: 0.5750 - loss: 0.6103 - val_box_output_loss: 0.0328 - val_box_output_mse: 0.0328 - val_class_output_accuracy: 0.9688 - val_class_output_loss: 0.1035 - val_loss: 0.1363
# Epoch 3/10
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - box_output_loss: 0.0292 - box_output_mse: 0.0292 - class_output_accuracy: 0.9518 - class_output_loss: 0.1187 - loss: 0.1479
# Epoch 3: val_class_output_loss improved from 0.10347 to 0.02722, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - box_output_loss: 0.0296 - box_output_mse: 0.0296 - class_output_accuracy: 0.9552 - class_output_loss: 0.1134 - loss: 0.1431 - val_box_output_loss: 0.0317 - val_box_output_mse: 0.0317 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0272 - val_loss: 0.0589
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - box_output_loss: 0.0303 - box_output_mse: 0.0303 - class_output_accuracy: 1.0000 - class_output_loss: 0.0290 - loss: 0.0593
# Epoch 4: val_class_output_loss improved from 0.02722 to 0.01362, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - box_output_loss: 0.0304 - box_output_mse: 0.0304 - class_output_accuracy: 1.0000 - class_output_loss: 0.0287 - loss: 0.0591 - val_box_output_loss: 0.0306 - val_box_output_mse: 0.0306 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0136 - val_loss: 0.0442
# Epoch 5/10
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - box_output_loss: 0.0356 - box_output_mse: 0.0356 - class_output_accuracy: 1.0000 - class_output_loss: 0.0137 - loss: 0.0493
# Epoch 5: val_class_output_loss improved from 0.01362 to 0.00867, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - box_output_loss: 0.0350 - box_output_mse: 0.0350 - class_output_accuracy: 1.0000 - class_output_loss: 0.0135 - loss: 0.0484 - val_box_output_loss: 0.0295 - val_box_output_mse: 0.0295 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0087 - val_loss: 0.0382
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - box_output_loss: 0.0290 - box_output_mse: 0.0290 - class_output_accuracy: 1.0000 - class_output_loss: 0.0086 - loss: 0.0375
# Epoch 6: val_class_output_loss improved from 0.00867 to 0.00636, saving model to dog_types.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - box_output_loss: 0.0289 - box_output_mse: 0.0289 - class_output_accuracy: 1.0000 - class_output_loss: 0.0085 - loss: 0.0375 - val_box_output_loss: 0.0292 - val_box_output_mse: 0.0292 - val_class_output_accuracy: 1.0000 - val_class_output_loss: 0.0064 - val_loss: 0.0356

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# %%
# img="datasets/bullmastiff1.jpg"
# print(img)

# %%
# image = load_img(img, target_size=(128,128))

# %%
# img_array=tf.keras.utils.img_to_array(image)
# norm=img_array/255.0
# img_batch=np.expand_dims(norm,axis=0)

# %%
# dog_type=detect_model.predict(img_batch)
# print(dog_type)
# # kelvin=np.argmax(dog_type)
# # kelvin

# %%
classe=['english_springer','westhighland_terrier','irish_wolfhound','bull_mastiff','whippet']

# %%
# predicted_classes = [np.argmax(p) for p in dog_type]
# predicted=predicted_classes[0]
# final_output=classe[predicted]
# print(final_output)

# %%
import gradio as gr

# %%
from PIL import Image

# %%
from PIL import Image

# %%
def dog_type_prediction(imge):
    img=imge.resize((128,128))
    img_array=tf.keras.utils.img_to_array(img)
    norm=img_array/255
    img_batch=np.expand_dims(norm,axis=0)

    dog_type=detect_model.predict(img_batch)
    predicted_classes=[np.argmax(p) for p in dog_type]
    predicted=predicted_classes[0]
    return classe[predicted]
    # return final_output

interface=gr.Interface(
    fn=dog_type_prediction,
    inputs=gr.Image(type='pil'),
    outputs=gr.Label(),
    title='dog_type prediction model',
    description='upload the dog image to see the output'
)
interface.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://793ff99d8b27e9ea19.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://793ff99d8b27e9ea19.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
# def prediction(image):
#     img=image.resize((128,128,3))
#     img_array=tf.keras.utils.img_to_array(img)
#     img_batch=np.expand_dims(img_array,axis=0)
#     predictions=detect_model.predict(img_batch)
#     index=np.argmax(predictions)
#     return classe[index]
# interface=gr.Interface(
#     fn=prediction,
#     inputs=gr.Image(type='pil'),
#     outputs=gr.Label(),
#     title='dog type prediction',
#     description='upload an image to see'
# )
# interface.launch(share=True)
